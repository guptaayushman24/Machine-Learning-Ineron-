# %%
## Install Pandas Data Reader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime
import yfinance as yfin

# %%
Tesla = yfin.Ticker('TSLA')

# %%
Tesla_data = Tesla.history(period="max")

# %%
df_tesla = Tesla_data

# %%
df_tesla.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
df_tesla.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and ylimit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and ylimit
df_tesla['High'].plot(xlim=['2020-01-01','2022-09-01'],ylim=[0,600],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and ylimit and coloring
df_tesla['High'].plot(xlim=['2020-01-01','2022-09-01'],ylim=[0,600],figsize=(12,4),c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and ylimit and coloring and line style
df_tesla['High'].plot(xlim=['2020-01-01','2022-09-01'],ylim=[0,600],figsize=(12,4),ls='--',c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29 00:00:00-04:00', '2010-06-30 00:00:00-04:00',
#                '2010-07-01 00:00:00-04:00', '2010-07-02 00:00:00-04:00',
#                '2010-07-06 00:00:00-04:00', '2010-07-07 00:00:00-04:00',
#                '2010-07-08 00:00:00-04:00', '2010-07-09 00:00:00-04:00',
#                '2010-07-12 00:00:00-04:00', '2010-07-13 00:00:00-04:00',
#                ...
#                '2023-10-02 00:00:00-04:00', '2023-10-03 00:00:00-04:00',
#                '2023-10-04 00:00:00-04:00', '2023-10-05 00:00:00-04:00',
#                '2023-10-06 00:00:00-04:00', '2023-10-09 00:00:00-04:00',
#                '2023-10-10 00:00:00-04:00', '2023-10-11 00:00:00-04:00',
#                '2023-10-12 00:00:00-04:00', '2023-10-13 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=3347, freq=None)

# %%
df_tesla.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
index=df_tesla.loc['2020-01-01':'2021-09-01'].index
share_open = df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02 00:00:00-05:00     28.299999
# 2020-01-03 00:00:00-05:00     29.366667
# 2020-01-06 00:00:00-05:00     29.364668
# 2020-01-07 00:00:00-05:00     30.760000
# 2020-01-08 00:00:00-05:00     31.580000
#                                 ...
# 2021-08-26 00:00:00-04:00    236.103333
# 2021-08-27 00:00:00-04:00    235.000000
# 2021-08-30 00:00:00-04:00    238.240005
# 2021-08-31 00:00:00-04:00    244.333328
# 2021-09-01 00:00:00-04:00    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_tesla.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
figure,axis=plt.subplots()
axis.plot(index,share_open)
plt.tight_layout()
# Prevting the overfitting
figure.autofmt_xdate()

# %% [markdown]
# Datetime Index

# %%
df_tesla = df_tesla.reset_index()

# %%
df_tesla.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3347 entries, 0 to 3346
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3347 non-null   datetime64[ns, America/New_York]
#  1   Open          3347 non-null   float64
#  2   High          3347 non-null   float64
#  3   Low           3347 non-null   float64
#  4   Close         3347 non-null   float64
#  5   Volume        3347 non-null   int64
#  6   Dividends     3347 non-null   float64
#  7   Stock Splits  3347 non-null   float64
# dtypes: datetime64[ns, America/New_York](1), float64(6), int64(1)
# memory usage: 209.3 KB

# %%
pd.to_datetime(df_tesla['Date'])
# Out:
# 0      2010-06-29 00:00:00-04:00
# 1      2010-06-30 00:00:00-04:00
# 2      2010-07-01 00:00:00-04:00
# 3      2010-07-02 00:00:00-04:00
# 4      2010-07-06 00:00:00-04:00
#                   ...
# 3342   2023-10-09 00:00:00-04:00
# 3343   2023-10-10 00:00:00-04:00
# 3344   2023-10-11 00:00:00-04:00
# 3345   2023-10-12 00:00:00-04:00
# 3346   2023-10-13 00:00:00-04:00
# Name: Date, Length: 3347, dtype: datetime64[ns, America/New_York]

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %% [markdown]
# # DateTime

# %%
from datetime import datetime

# %%
# Creating the new date
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
# Current date and time
datetime.now()
# Out:
# datetime.datetime(2023, 10, 16, 11, 10, 26, 88878)

# %%
def add_num(num1,num2) :
    return num1+num2

# %%
# Masuring how much time is taking these particular function
num1=20
num2=30
start_time = datetime.now()
add_num(num1,num2)
end_time = datetime.now()

# %%
print(start_time-end_time)
# Out:
# 0:00:00

# %%
date = datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %% [markdown]
# Time Resampling

# %%
df_tesla.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
df_tesla.resample(rule='A').min()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-12-31 00:00:00-05:00    1.076000    1.108667    0.998667    1.053333
# 2011-12-31 00:00:00-05:00    1.452000    1.484667    1.407333    1.455333
# 2012-12-31 00:00:00-05:00    1.774667    1.790000    1.509333    1.519333
# 2013-12-31 00:00:00-05:00    2.205333    2.225333    2.140667    2.194000
# 2014-12-31 00:00:00-05:00    9.366667    9.800000    9.111333    9.289333
# 2015-12-31 00:00:00-05:00   12.388667   12.619333   12.093333   12.333333
# 2016-12-31 00:00:00-05:00    9.488000   10.331333    9.403333    9.578000
# 2017-12-31 00:00:00-05:00   14.316667   14.688667   14.064000   14.466000
# 2018-12-31 00:00:00-05:00   16.851999   17.355333   16.306000   16.704000
# 2019-12-31 00:00:00-05:00   12.073333   12.445333   11.799333   11.931333
# 2020-12-31 00:00:00-05:00   24.980000   26.990667   23.367332   24.081333
# 2021-12-31 00:00:00-05:00  184.183334  188.736664  179.830002  187.666672
# ...

# %%
df_tesla.resample(rule='A').max()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-12-31 00:00:00-05:00    2.391333    2.428000    2.316667    2.364667
# 2011-12-31 00:00:00-05:00    2.308667    2.333333    2.268667    2.329333
# 2012-12-31 00:00:00-05:00    2.546000    2.663333    2.474000    2.534000
# 2013-12-31 00:00:00-05:00   12.930667   12.966667   12.558000   12.891333
# 2014-12-31 00:00:00-05:00   19.177999   19.427999   18.693333   19.069332
# 2015-12-31 00:00:00-05:00   18.680000   19.110001   18.420000   18.817333
# 2016-12-31 00:00:00-05:00   17.763332   17.955999   16.967333   17.694668
# 2017-12-31 00:00:00-05:00   25.779333   25.974001   25.290001   25.666668
# 2018-12-31 00:00:00-05:00   25.000000   25.830667   24.474667   25.304667
# 2019-12-31 00:00:00-05:00   29.000000   29.020666   28.423332   28.729334
# 2020-12-31 00:00:00-05:00  233.330002  239.573334  230.373337  235.223328
# 2021-12-31 00:00:00-05:00  411.470001  414.496674  405.666656  409.970001
# ...

# %%
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Quaterly information
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Business End Frequency
df_tesla.resample(rule='BA').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High']
# Out:
# Date
# 2010-06-29 00:00:00-04:00      1.666667
# 2010-06-30 00:00:00-04:00      2.028000
# 2010-07-01 00:00:00-04:00      1.728000
# 2010-07-02 00:00:00-04:00      1.540000
# 2010-07-06 00:00:00-04:00      1.333333
#                                 ...
# 2023-10-09 00:00:00-04:00    261.359985
# 2023-10-10 00:00:00-04:00    268.940002
# 2023-10-11 00:00:00-04:00    268.600006
# 2023-10-12 00:00:00-04:00    265.410004
# 2023-10-13 00:00:00-04:00    259.600006
# Name: High, Length: 3347, dtype: float64

# %%
df_tesla['High'].rolling(10).mean()
# Out:
# Date
# 2010-06-29 00:00:00-04:00           NaN
# 2010-06-30 00:00:00-04:00           NaN
# 2010-07-01 00:00:00-04:00           NaN
# 2010-07-02 00:00:00-04:00           NaN
# 2010-07-06 00:00:00-04:00           NaN
#                                 ...
# 2023-10-09 00:00:00-04:00    254.996999
# 2023-10-10 00:00:00-04:00    256.935999
# 2023-10-11 00:00:00-04:00    259.262999
# 2023-10-12 00:00:00-04:00    261.048999
# 2023-10-13 00:00:00-04:00    261.531999
# Name: High, Length: 3347, dtype: float64

# %%
df_tesla['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2010-06-29 00:00:00-04:00         NaN
# 2010-06-30 00:00:00-04:00         NaN
# 2010-07-01 00:00:00-04:00         NaN
# 2010-07-02 00:00:00-04:00         NaN
# 2010-07-06 00:00:00-04:00         NaN
# 2010-07-07 00:00:00-04:00         NaN
# 2010-07-08 00:00:00-04:00         NaN
# 2010-07-09 00:00:00-04:00         NaN
# 2010-07-12 00:00:00-04:00         NaN
# 2010-07-13 00:00:00-04:00    1.421333
# 2010-07-14 00:00:00-04:00    1.389000
# 2010-07-15 00:00:00-04:00    1.329533
# 2010-07-16 00:00:00-04:00    1.298733
# 2010-07-19 00:00:00-04:00    1.293067
# 2010-07-20 00:00:00-04:00    1.305400
# 2010-07-21 00:00:00-04:00    1.333867
# 2010-07-22 00:00:00-04:00    1.358733
# 2010-07-23 00:00:00-04:00    1.383133
# 2010-07-26 00:00:00-04:00    1.406000
# 2010-07-27 00:00:00-04:00    1.422933
# Name: High, dtype: float64

# %%
df_tesla['Open : 30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-10-09 00:00:00-04:00  255.309998  261.359985  252.050003  259.670013
# 2023-10-10 00:00:00-04:00  257.750000  268.940002  257.649994  263.619995
# 2023-10-11 00:00:00-04:00  266.200012  268.600006  260.899994  262.989990
# 2023-10-12 00:00:00-04:00  262.920013  265.410004  256.630005  258.869995
# 2023-10-13 00:00:00-04:00  258.899994  259.600006  250.220001  251.119995
#
#                               Volume  Dividends  Stock Splits  \
# Date
# ...

# %%
df_tesla[['Open','Open : 30 days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Orange line is the smoothner version of the blue line

# %%
## Assignment
## News
# 1-> Read the Microsoft Data using Pandas Data reader
# 2-> Get the maximum price of the share from 2017 and 2022
# 3-> Which is the date of the highest price of the stock
# 4-> Which is the date of the lowest price of the stock
